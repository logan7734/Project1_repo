# %%
import pandas as pd
import numpy as np
from pandas import ExcelFile

# %%
ball_data = pd.read_excel("NBA+Data.xlsx", sheetname ="NBA+Data")
# Out:
# C:\Users\12812\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)

# %%
ball_data.head()
# Out:
#      Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950.0  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950.0     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950.0    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950.0       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950.0       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
ball_data["Year"] = ball_data["Year"].fillna(0)

# %%
ball_data.head()
# Out:
#    Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
ball_data["Year"] = ball_data["Year"].astype(int)

# %%
ball_data.head()
# Out:
#    Year           Player  Pos   Age   Tm     G  GS  MP  PER    TS%  ...    \
# 0  1950  Curly Armstrong  G-F  31.0  FTW  63.0 NaN NaN  NaN  0.368  ...
# 1  1950     Cliff Barker   SG  29.0  INO  49.0 NaN NaN  NaN  0.435  ...
# 2  1950    Leo Barnhorst   SF  25.0  CHS  67.0 NaN NaN  NaN  0.394  ...
# 3  1950       Ed Bartels    F  24.0  TOT  15.0 NaN NaN  NaN  0.312  ...
# 4  1950       Ed Bartels    F  24.0  DNN  13.0 NaN NaN  NaN  0.308  ...
#
#      FT%  ORB  DRB  TRB    AST  STL  BLK  TOV     PF    PTS
# 0  0.705  NaN  NaN  NaN  176.0  NaN  NaN  NaN  217.0  458.0
# 1  0.708  NaN  NaN  NaN  109.0  NaN  NaN  NaN   99.0  279.0
# 2  0.698  NaN  NaN  NaN  140.0  NaN  NaN  NaN  192.0  438.0
# 3  0.559  NaN  NaN  NaN   20.0  NaN  NaN  NaN   29.0   63.0
# 4  0.548  NaN  NaN  NaN   20.0  NaN  NaN  NaN   27.0   59.0
#
# [5 rows x 52 columns]

# %%
#import file with players height and weight. will merge this with the ball_data dataframe
height_weight = pd.read_excel("player_heightweight_data.xlsx", sheet_name ="player_data")

# %%
height_weight.head()
# Out:
#                   name  year_start  year_end position     height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C 2019-06-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F 2019-06-09   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C 2019-07-02   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G 2019-06-01   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F 2019-06-06   223.0
#
#   birth_date                                college
# 0 1968-06-24                        Duke University
# 1 1946-04-07                  Iowa State University
# 2 1947-04-16  University of California, Los Angeles
# 3 1969-03-09             Louisiana State University
# 4 1974-11-03              San Jose State University

# %%
list(height_weight)
# Out:
# ['name',
#  'year_start',
#  'year_end',
#  'position',
#  'height',
#  'weight',
#  'birth_date',
#  'college']

# %%
#renaming the first column to match the ball_data
height_weight = height_weight.rename(columns ={'name':'Player'})
height_weight.head()
# Out:
#                 Player  year_start  year_end position     height  weight  \
# 0       Alaa Abdelnaby        1991      1995      F-C 2019-06-10   240.0
# 1      Zaid Abdul-Aziz        1969      1978      C-F 2019-06-09   235.0
# 2  Kareem Abdul-Jabbar        1970      1989        C 2019-07-02   225.0
# 3   Mahmoud Abdul-Rauf        1991      2001        G 2019-06-01   162.0
# 4    Tariq Abdul-Wahad        1998      2003        F 2019-06-06   223.0
#
#   birth_date                                college
# 0 1968-06-24                        Duke University
# 1 1946-04-07                  Iowa State University
# 2 1947-04-16  University of California, Los Angeles
# 3 1969-03-09             Louisiana State University
# 4 1974-11-03              San Jose State University

# %%
bd_merged = pd.merge(ball_data, height_weight, on = "Player")

# %%
bd_merged.head()
# Out:
#    Year           Player  Pos   Age   Tm     G  GS     MP   PER    TS%  \
# 0  1950  Curly Armstrong  G-F  31.0  FTW  63.0 NaN    NaN   NaN  0.368
# 1  1951  Curly Armstrong  G-F  32.0  FTW  38.0 NaN    NaN   NaN  0.372
# 2  1950     Cliff Barker   SG  29.0  INO  49.0 NaN    NaN   NaN  0.435
# 3  1951     Cliff Barker   SG  30.0  INO  56.0 NaN    NaN   NaN  0.322
# 4  1952     Cliff Barker   SG  31.0  INO  44.0 NaN  494.0  10.8  0.343
#
#             ...            TOV     PF    PTS  year_start  year_end  position  \
# 0           ...            NaN  217.0  458.0        1949      1951       G-F
# 1           ...            NaN   97.0  202.0        1949      1951       G-F
# 2           ...            NaN   99.0  279.0        1950      1952         G
# 3           ...            NaN   98.0  152.0        1950      1952         G
# 4           ...            NaN   56.0  126.0        1950      1952         G
#
#       height  weight  birth_date                 college
# ...

# %%
#
